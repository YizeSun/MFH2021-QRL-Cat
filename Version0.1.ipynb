# %%
from copy import deepcopy
import numpy as np
import random
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit import Aer, transpile, assemble
from qiskit.providers import backend
from qiskit.aqua.components.optimizers import COBYLA

# %%
#
CAT = "c"
DOG = "d"
MOUSE = "m"
EMPTY = "emp"

# gridWorld = [[MOUSE, EMPTY, DOG],
#         [EMPTY, EMPTY, EMPTY],
#          [DOG, EMPTY, CAT]]

# actions:
UP = "00"
DOWN = "01"
LEFT = "10"
RIGHT = "11"

ACTIONS = [UP, DOWN, LEFT, RIGHT]

# %%
class State:
    def __init__(self, catP):
        self.row = catP[0]
        self.column = catP[1]
        self.catP = catP

    def __eq__(self, other):
        return isinstance(other, State) and self.row == other.row and self.column == other.column and self.catP == other.catP

    def __hash__(self):
        return hash(str(self.catP))

    def __str__(self):
        return f"State(cat_pos={self.catP})"

# %%
class GridWorld:
    def __init__(self, s, catP, mouseP):
        self.numRows = s[0]
        self.numColumns = s[1]
        self.catP = catP
        self.mouseP = mouseP
        # self.dogP = dogP
        assert(not self.compaireList(self.catP, self.mouseP))
    
    def getItem(self, p):
        if p[0]>=self.numRows or p[0]<0:
            return None
        if p[1]>=self.numColumns or p[1]<0:
            return None
        if self.compaireList(p, catP):
            return CAT
        elif self.compaireList(p, mouseP):
            return MOUSE
        # elif self.compaireList(p, DOG):
        #     return DOG
        else:
            return EMPTY

    def compaireList(self, l1,l2):
        for i, j in zip(l1, l2):
            if i!=j:
                return False
        return True

    def getNumRows(self):
        return self.numRows

    def getNumColumns(self):
        return self.numColumns

    def getMouse(self):
        return self.mouse
    
    def getCatP(self):
        return self.catP

    def setCatP(self, p):
        self.catP = p
    
    def initCatState(self):
        # init cat position
        catP = [random.randint(0, self.getNumRows()), random.randint(0, self.getNumColumns())]
        while self.getItem(catP) != EMPTY and self.getItem(catP) != CAT:
            catP = [random.randint(0, self.getNumRows()), random.randint(0, self.getNumColumns())]
        self.setCatP(catP)
        return State(catP)
    
    def show(self):
        output = ""
        for i in range(self.numRows):
            for j in range(self.numColumns):
                if self.compaireList([i,j], self.catP):
                    output += CAT + " "
                elif self.compaireList([i,j], self.mouseP):
                    output += MOUSE + " "
                else:
                    output += EMPTY + " "
            output += "\n"
        print(output)

# %%
# agent: cat
class cat:
    
    def __init__(self, eps, qTable, gridWorld, training):
        self.eps = eps
        self.qt = qTable #dictionary
        self.gw = gridWorld # field 
        self.params = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
        self.training = training # For future development 
        self.qcs = self.initQC(ret[0]) # QUESTION!!! Random or not???
        
        self.state = None
        

    def newPosition(self, state, action):
            p = deepcopy(state.catP)
            if action == UP:
                p[0] = max(0, p[0] - 1)
            elif action == DOWN:
                p[0] = min(len(self.gw) - 1, p[0]+1)
            elif action == LEFT:
                p[1] = max(0, p[1] - 1)
            elif action == RIGHT:
                p[1] = min(len(self.gw) - 1, p[1] + 1)
            else:
                raise ValueError(f"Unkown action {action}")
            return p

    def getReward(self, p):
        grid = self.gw[p[0]][p[1]]
        if grid == DOG:
            reward = -100
            end = True
            self.gw[p[0]][p[1]] += CAT
        elif grid == MOUSE:
            reward = 100
            end = True
            self.gw[p[0]][p[1]] += CAT
        elif grid == EMPTY:
            reward = -1
            end = False
            old = state.catP
            self.gw[old[0]][old[1]] = EMPTY
            self.gw[p[0]][p[1]] = CAT
        elif grid == CAT:
            reward = -1
            end = False
        else:
            raise ValueError(f"Unknown grid item {grid}")
        return reward, end

    def act(self, state, action):
        p = self.newPosition(state, action)
        reward, end = self.getReward(p)
        return deepcopy[p], reward, end
        
    def setTraining(self, training):
        self.training = training # The big T was there

# %%
# quantum circuit: state->action
class qNetwork:# just a place for 
    
    def __init__(self, qTable, gridWorld, params, eps):
        
        self.params = params # inital parameters are the same for all qNetwork
        self.gw = gridWorld
        self.qt = qTable
        self.eps = eps
        self.backend = Aer.get_backend("qasm_simulator")
        self.NUM_SHOTS = 1000 # number of measurements 
        self.optimizer = COBYLA(maxiter=500, tol=0.0001) # off the shelf
        
        self.qcs = None # all qubits
        self.rets = None # resulting parameters after optimization for all points in the grid
        
        
        self.qc = None # qubit of current state
        self.state = None
        
    
        qcs = {}
        def qcMaker(params):
            qr = QuantumRegister(2, name="q")
            cr = ClassicalRegister(2, name="c")
            qc = QuantumCircuit(qr, cr)
            qc.u3(self.params[0], self.params[1], self.params[2], qr[0])
            qc.u3(self.params[3], self.params[4], self.params[5], qr[1])
            qc.cx(qr[0], qr[1])
            qc.measure(qr, cr)
            return qc

        for i in range(self.gw.getNumRows()):
            for j in range(self.gw.getNumRows()):
                qc = qcMaker(params)
                qcs[i, j] = qc 
    
        self.qcs = qcs
    
    
    def selectAction(self, state, training):
        if random.uniform(0, 1) < self.eps:
            return random.choice(ACTIONS)
        else:
            if training:
                qc = self.qcs[state.row, state.column]
                self.state = state
                self.updateCircuit(state)
            return np.argmax(self.qt[state])
        
    def lossFunction(self, params):
        state = self.state
        qc = self.qc
        t_qc = transpile(qc, self.backend)
        job = assemble(t_qc, shots=self.NUM_SHOTS)
        rlt = self.backend.run(job).result()
        counts = rlt.get_counts(qc)
        action = max(counts, key = counts.get)
        nextPosition = self.newPosition(state, action) # handle the 
        reward, _ = self.getReward(nextPosition)
        # update q-table(but not very sure, update only for this action or for all actions)
        targetQvalue = reward + gamma *  np.max(self.qt[State(nextPosition)])
        if targetQvalue - self.qt[state][action] > 0:
            self.qt[state][action] += alpha * (targetQvalue - self.qt[state][action]) # update q-table
        return targetQvalue - self.qt[state][action]

    
    def updateCircuit(self, state):
        self.rets[state] = self.optimizer.optimize(num_vars=6, objective_function=self.lossFunction, initial_point=self.params)

# %%
gridSize = [3, 3]
catP = [gridSize[0]-1, gridSize[0]-1]
mouseP = [0, 0]

# initQTable
def initqTable(ACTIONS): #self was there
        side = 2 # Number of cells per side of the grid
        d = {}
        for i in range(side):
            for j in range(side):
                d[(i,j)] = np.random.random()

        return d
# initGridWorld
gridWorld = GridWorld(gridSize, catP=catP, mouseP=mouseP)
gridWorld.show()
qTable = initqTable(ACTIONS)
# Out:
# m emp emp
# emp emp emp
# emp emp c

# %%
# super parameters
N_STATES = 4
N_EPISODES = 20

MAX_EPISODE_STEPS = 100

MIN_ALPHA = 0.02

alphas = np.linspace(1.0, MIN_ALPHA, N_EPISODES)
gamma = 1.0
eps = 0.2

initialParameters = np.array([0 for i in range(0,6)]) # Same for all qubits!

# %%
initialParameters = np.array([0 for i in range(0,6)])
initialParameters
# Out:
# array([0, 0, 0, 0, 0, 0])

# %%
qNetwork = qNetwork(qTable, gridWorld, initialParameters, eps)
print(qNetwork.selectAction(State(catP),True))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-122-874bf21aab06> in <module>
#       1 qNetwork = qNetwork(qTable, gridWorld, initialParameters, eps)
# ----> 2 print(qNetwork.selectAction(State(catP),True))
#
# <ipython-input-118-1d41ae358515> in selectAction(self, state, training)
#      46                 qc = self.qcs[state.row, state.column]
#      47                 self.state = state
# ---> 48                 self.updateCircuit(state)
#      49             return np.argmax(self.qt[state])
#      50
#
# <ipython-input-118-1d41ae358515> in updateCircuit(self, state)
#      67
#      68     def updateCircuit(self, state):
# ---> 69         self.rets[state] = self.optimizer.optimize(num_vars=6, objective_function=self.lossFunction, initial_point=self.params)
#
# ~/anaconda3/lib/python3.8/site-packages/qiskit/aqua/components/optimizers/cobyla.py in optimize(self, num_vars, objective_function, gradient_function, variable_bounds, initial_point)
#      69                          variable_bounds, initial_point)
#      70
# ---> 71         res = minimize(objective_function, initial_point, tol=self._tol,
#      72                        method="COBYLA", options=self._options)
#      73         return res.x, res.fun, res.nfev
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     623                              **options)
#     624     elif meth == 'cobyla':
# --> 625         return _minimize_cobyla(fun, x0, args, constraints, **options)
#     626     elif meth == 'slsqp':
#     627         return _minimize_slsqp(fun, x0, args, jac, bounds,
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/optimize/cobyla.py in wrapper(*args, **kwargs)
#      32     def wrapper(*args, **kwargs):
#      33         with _module_lock:
# ---> 34             return func(*args, **kwargs)
#      35     return wrapper
#      36
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/optimize/cobyla.py in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, **unknown_options)
#     258
#     259     info = np.zeros(4, np.float64)
# --> 260     xopt, info = _cobyla.minimize(calcfc, m=m, x=np.copy(x0), rhobeg=rhobeg,
#     261                                   rhoend=rhoend, iprint=iprint, maxfun=maxfun,
#     262                                   dinfo=info)
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/optimize/cobyla.py in calcfc(x, con)
#     250
#     251     def calcfc(x, con):
# --> 252         f = fun(x, *args)
#     253         i = 0
#     254         for size, c in izip(cons_lengths, constraints):
#
# <ipython-input-118-1d41ae358515> in lossFunction(self, params)
#      52         state = self.state
#      53         qc = self.qc
# ---> 54         t_qc = transpile(qc, self.backend)
#      55         job = assemble(t_qc, shots=self.NUM_SHOTS)
#      56         rlt = self.backend.run(job).result()
#
# ~/anaconda3/lib/python3.8/site-packages/qiskit/compiler/transpiler.py in transpile(circuits, backend, basis_gates, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, pass_manager, callback, output_name)
#     267
#     268     # Get transpile_args to configure the circuit transpilation job(s)
# --> 269     transpile_args = _parse_transpile_args(
#     270         circuits,
#     271         backend,
#
# ~/anaconda3/lib/python3.8/site-packages/qiskit/compiler/transpiler.py in _parse_transpile_args(circuits, backend, basis_gates, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, seed_transpiler, optimization_level, callback, output_name, timing_constraints)
#     500     seed_transpiler = _parse_seed_transpiler(seed_transpiler, num_circuits)
#     501     optimization_level = _parse_optimization_level(optimization_level, num_circuits)
# --> 502     output_name = _parse_output_name(output_name, circuits)
#     503     callback = _parse_callback(callback, num_circuits)
#     504     durations = _parse_instruction_durations(backend, instruction_durations, dt, circuits)
#
# ~/anaconda3/lib/python3.8/site-packages/qiskit/compiler/transpiler.py in _parse_output_name(output_name, circuits)
#     859             )
#     860     else:
# --> 861         return [circuit.name for circuit in circuits]
#     862
#     863
#
# ~/anaconda3/lib/python3.8/site-packages/qiskit/compiler/transpiler.py in <listcomp>(.0)
#     859             )
#     860     else:
# --> 861         return [circuit.name for circuit in circuits]
#     862
#     863
#
# AttributeError: 'NoneType' object has no attribute 'name'
